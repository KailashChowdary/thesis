# %%
options = webdriver.ChromeOptions()
options.add_experimental_option("useAutomationExtension", False)
options.add_experimental_option("excludeSwitches",["enable-automation"])

driver_path = 'chromedriver'
driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)
#browser = webdriver.Chrome()
driver.delete_all_cookies()    
driver.maximize_window()
driver.get('https://database.globalreporting.org/reports/8012/download-report-pdf/')
time.sleep(5)
driver.switch_to.frame(driver.find_element_by_tag_name("iframe"))
time.sleep(5)
driver.find_element_by_xpath("//*[@id='recaptcha-anchor']/div[1]").click()
time.sleep(5)
driver.switch_to_default_content()

#driver.close()
# Out:
# <ipython-input-11-8b36cae7ef0c>:6: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)
# <ipython-input-11-8b36cae7ef0c>:16: DeprecationWarning: use driver.switch_to.default_content instead
#   driver.switch_to_default_content()

# %%
ll = kb[kb['Publication Year']==2015]
for i in ll['Unique'].dropna().unique():
            driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)
            driver.delete_all_cookies()    
            driver.maximize_window()
            driver.get(i)
            time.sleep(5)
            mouse = Controller()
            mouse.position = (320, 72)
            time.sleep(10)
            mouse.move(850, 30)
            time.sleep(5)
            mouse.press(Button.left)
            time.sleep(1)
            mouse.release(Button.left)
            time.sleep(5)
            mouse = Controller()
            mouse.position = (320, 72)
            time.sleep(5)
            mouse.move(150, 380)
            time.sleep(5)
            mouse.press(Button.left)
            time.sleep(1)
            mouse.release(Button.left)
            time.sleep(10)
            driver.close()

# %%
import pyautogui
import time

# To simulate a Save As dialog. You can remove this since you'll be saving/downloading a file from a link
pyautogui.hotkey('ctrl', 's')
# Wait for the Save As dialog to load. Might need to increase the wait time on slower machines
time.sleep(1)
# File path + name
FILE_NAME = 'C:\\path\\to\\file\\file.ext'
# Type the file path and name is Save AS dialog
pyautogui.typewrite(FILE_NAME)
#Hit Enter to save
pyautogui.hotkey('enter')

# %%
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from pynput.mouse import Button, Controller
options = webdriver.ChromeOptions()
from pynput.mouse import Button, Controller
import time 
import pyautogui

# %%
options.add_experimental_option("useAutomationExtension", False)
options.add_experimental_option("excludeSwitches",["enable-automation"])

driver_path = 'chromedriver'
driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)

driver.delete_all_cookies()    
driver.maximize_window()
driver.get('https://database.globalreporting.org/reports/8012/download-report-pdf/')
time.sleep(5)
mouse = Controller()
mouse.position = (320, 72)
time.sleep(5)
mouse.move(170, 500)
time.sleep(5)
mouse.press(Button.left)
#time.sleep(2)
mouse.release(Button.left)
# Out:
# <ipython-input-12-ef47067f1836>:5: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)

# %%
options = webdriver.ChromeOptions()
options.add_experimental_option("useAutomationExtension", False)
options.add_experimental_option("excludeSwitches",["enable-automation"])

driver_path = 'chromedriver'
driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)
time.sleep(5)
driver.maximize_window()
driver.delete_all_cookies()    
#driver.maximize_window()
driver.get('https://www.abertis.com/abertis_informe_anual_06/IRSC06EN/PDF/doc.pdf')
time.sleep(5)
mouse = Controller()
mouse.position = (320, 72)
time.sleep(10)
mouse.move(1450, 50)
time.sleep(5)
mouse.press(Button.left)
time.sleep(1)
mouse.release(Button.left)
time.sleep(5)
mouse = Controller()
mouse.position = (320, 72)
time.sleep(5)
mouse.move(410, 600)
time.sleep(5)
mouse.press(Button.left)
time.sleep(1)
mouse.release(Button.left)
time.sleep(10)
driver.close()
# Out:
# <ipython-input-38-3abf2bbdeb16>:6: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)

# %%
driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)
driver.maximize_window()
# Out:
# <ipython-input-11-197a1454cc90>:1: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)

# %%
pip install pyautogui
# Out:
# Collecting pyautogui
# Note: you may need to restart the kernel to use updated packages.
#   Downloading PyAutoGUI-0.9.52.tar.gz (55 kB)
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting PyTweening>=1.0.1
#   Downloading PyTweening-1.0.3.zip (15 kB)
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.26.tar.gz (23 kB)
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
# Requirement already satisfied: Pillow>=6.2.1 in c:\users\chowd\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (8.0.1)
# Collecting pyrect
#   Downloading PyRect-0.1.4.tar.gz (15 kB)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Building wheels for collected packages: pyautogui, pymsgbox, PyTweening, pyscreeze, pygetwindow, mouseinfo, pyrect, pyperclip
#   Building wheel for pyautogui (setup.py): started
#   Building wheel for pyautogui (setup.py): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.52-py3-none-any.whl size=35198 sha256=8f7f04476796dd011ddd5213bfb2f77ff501db778634db718b32229eb16742b2
#   Stored in directory: c:\users\chowd\appdata\local\pip\cache\wheels\4d\0d\6a\4258cb741835ea9ce7897652ae88272d3baf5cb1944c1984aa
#   Building wheel for pymsgbox (PEP 517): started
#   Building wheel for pymsgbox (PEP 517): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7420 sha256=b06d26fa8d75b79a2528404061d8445d0586afb7395b95b7d810542da8958b83
#   Stored in directory: c:\users\chowd\appdata\local\pip\cache\wheels\91\28\0d\f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for PyTweening (setup.py): started
#   Building wheel for PyTweening (setup.py): finished with status 'done'
#   Created wheel for PyTweening: filename=PyTweening-1.0.3-py3-none-any.whl size=3820 sha256=69f5c92be59da1f9d260d66a572c1b33691a20fb87e45c2ba3589341b63ca2e6
#   Stored in directory: c:\users\chowd\appdata\local\pip\cache\wheels\e7\50\20\790fbd95739abfdf0348bef99d5cc0c7c2930a19a91f602ddc
#   Building wheel for pyscreeze (setup.py): started
#   Building wheel for pyscreeze (setup.py): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.26-py3-none-any.whl size=11937 sha256=f6f4d7da9216b984b9ff6e9ee1f1f1e739d20e287d686f1af2381be6d3219bcb
#   Stored in directory: c:\users\chowd\appdata\local\pip\cache\wheels\b9\1c\f2\f6a3a846873ff464c47a46baa7edc12fb5f266d296494201fe
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11084 sha256=563ef5f075bc60c25cf751dbe3faf32aa975aa470b669dce395140866657d92a
#   Stored in directory: c:\users\chowd\appdata\local\pip\cache\wheels\91\e3\04\184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10910 sha256=cf4661b4813f5f7d8a5ddb50cd1c0b160a922fa8d111ec32af07b0f047c9173a
#   Stored in directory: c:\users\chowd\appdata\local\pip\cache\wheels\d1\72\fb\35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.1.4-py2.py3-none-any.whl size=9552 sha256=be1e27a537b15432457a5ff7489a4d54afee614c4022eb0379e6457c9051091a
#   Stored in directory: c:\users\chowd\appdata\local\pip\cache\wheels\d1\e4\47\c62f8291b16b6df7e89ac885881ff71f35ca04c6e384251de9
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11112 sha256=9e7e8e64e8d915730e3a8563481827b4ad0f60f03a24a6a8bd16becde7dcbce0
#   Stored in directory: c:\users\chowd\appdata\local\pip\cache\wheels\7f\1a\65\84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
# Successfully built pyautogui pymsgbox PyTweening pyscreeze pygetwindow mouseinfo pyrect pyperclip
# Installing collected packages: pymsgbox, PyTweening, pyscreeze, pyrect, pygetwindow, pyperclip, mouseinfo, pyautogui
# Successfully installed PyTweening-1.0.3 mouseinfo-0.1.3 pyautogui-0.9.52 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.1.4 pyscreeze-0.1.26

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from pynput.mouse import Button, Controller
options = webdriver.ChromeOptions()
from pynput.mouse import Button, Controller
import time 
import pyautogui

# %% [markdown]
# df=pd.ExcelFile('C://Users//chowd//Downloads//Thesis//GRI-Reports-List-1999 to 2017.xlsx')

# %%
dfk=pd.read_excel('C://Users//chowd//Downloads//Thesis//GRI-Reports-List-1999 to 2017.xlsx',sheet_name=None)

# %%
mdf = pd.concat(dfk, axis=0, ignore_index=True)

# %%
mdf
# Out:
#                                Name   Size                      Sector  \
# 0                              Acea  Large            Energy Utilities
# 1      Bristol-Myers Squibb Company  Large         Healthcare Products
# 2                   British Airways  Large                    Aviation
# 3                        Electrolux  Large           Consumer Durables
# 4                              ESAB  Large      Construction Materials
# ...                             ...    ...                         ...
# 49940               ZTE Corporation  Large         Technology Hardware
# 49941     Zuellig Family Foundation    SME       Non-Profit / Services
# 49942          Zürcher Kantonalbank  Large          Financial Services
# 49943        Zurich Insurance Group  Large          Financial Services
# 49944             Zwack Unicum Nyrt  Large  Food and Beverage Products
#
#                                                  Country Country Status  \
# 0                                                  Italy           OECD
# 1                               United States of America           OECD
# 2      United Kingdom of Great Britain and Northern I...           OECD
# 3                                                 Sweden           OECD
# 4                                                 Sweden           OECD
# ...                                                  ...            ...
# 49940                                     Mainland China      DAC-UMICT
# 49941                                        Philippines      DAC-LMICT
# 49942                                        Switzerland           OECD
# 49943                                        Switzerland           OECD
# 49944                                            Hungary           OECD
#
#                  Region  Date Added  \
# 0                Europe   19-2-2007
# 1      Northern America  12-11-2008
# 2                Europe  27-10-2009
# 3                Europe    9-2-2009
# 4                Europe  12-11-2008
# ...                 ...         ...
# 49940              Asia    6-6-2017
# 49941              Asia   25-9-2018
# 49942            Europe   5-10-2017
# 49943            Europe   25-4-2017
# 49944            Europe   23-2-2020
#
#                                                Title  Publication Year  \
# 0               Social and Environmental report 1998              1999
# 1                            Sustainability Progress              1999
# 2                   Annual Environmental Report 1999              1999
# 3                          Environmental Report 1998              1999
# 4              ESAB's Sustainable Development Report              1999
# ...                                              ...               ...
# 49940                     Sustainability Report 2016              2017
# 49941          Annual and Sustainability Report 2016              2017
# 49942  Nachhaltigkeitsbericht zum Geschäftsjahr 2016              2017
# 49943       2016 Corporate Responsibility Highlights              2017
# 49944                     Sustainability Report 2017              2017
#
#                 Type  ... Assurance Standard: AA1000 AS  \
# 0           GRI - G1  ...                           NaN
# 1           GRI - G1  ...                           NaN
# 2           GRI - G1  ...                           NaN
# 3           GRI - G1  ...                           NaN
# 4           GRI - G1  ...                           NaN
# ...              ...  ...                           ...
# 49940       GRI - G4  ...                            No
# 49941       GRI - G4  ...                           Yes
# 49942       GRI - G4  ...                            No
# 49943      Non - GRI  ...                            No
# 49944  GRI-Standards  ...                            No
#
#       Assurance Stanadard: ISAE3000  Assurance Standard: national (general)  \
# 0                               NaN                                     NaN
# 1                               NaN                                     NaN
# 2                               NaN                                     NaN
# 3                               NaN                                     NaN
# 4                               NaN                                     NaN
# ...                             ...                                     ...
# 49940                            No                                      No
# 49941                            No                                      No
# 49942                            No                                      No
# 49943                            No                                      No
# 49944                            No                                      No
#
#       Assurance Standard: national (sustainability) Materiality Matters Check  \
# 0                                               NaN                       NaN
# 1                                               NaN                       NaN
# 2                                               NaN                       NaN
# 3                                               NaN                       NaN
# 4                                               NaN                       NaN
# ...                                             ...                       ...
# 49940                                            No                       NaN
# 49941                                            No                       NaN
# 49942                                            No                       NaN
# 49943                                            No                       NaN
# 49944                                            No                       NaN
#
#                            GRI Service Featured Report?   OS GOLD Community  \
# 0                                  NaN              NaN  NaN            NaN
# 1                                  NaN              NaN  NaN            NaN
# 2                                  NaN              NaN  NaN            NaN
# 3                                  NaN              NaN  NaN            NaN
# 4                                  NaN              NaN  NaN            NaN
# ...                                ...              ...  ...            ...
# 49940                              NaN               No  NaN             No
# 49941  Materiality Disclosures Service               No  NaN             No
# 49942  Materiality Disclosures Service               No  NaN             No
# 49943                              NaN               No  NaN             No
# 49944                              NaN               No  NaN             No
#
#       SDGs
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ...    ...
# 49940   No
# 49941   No
# 49942   No
# 49943  NaN
# 49944  Yes
#
# [49945 rows x 43 columns]

# %%
mdf[49900:49945]
# Out:
#                                                     Name   Size  \
# 49900                   Zhejiang Mintai Commmercial Bank  Large
# 49901                                       Zhejiang Nhu  Large
# 49902           ZHEJIANG NOBLELIFT EQUIPMENT JOINT STOCK  Large
# 49903                   Zhejiang Provincial Energy Group  Large
# 49904          ZHEJIANG WEIMING ENVIRONMENTAL PROTECTION  Large
# 49905            ZHEJIANG WEIXING INDUSTRIAL DEVELOPMENT  Large
# 49906            Zhejiang Weixing New Building Materials  Large
# 49907           ZHEJIANG XINAN CHEMICAL INDUSTRIAL GROUP  Large
# 49908                                    ZHEJIANG YANKON  Large
# 49909                          ZHEJIANG YASHA DECORATION  Large
# 49910               Zhen Ding Technology Holding Limited    MNE
# 49911             Zhengzhou Coal Mining Machinery Group   Large
# 49912                     Zhengzhou Newcapec Electronics    SME
# 49913                               Zhengzhou Yutong Bus  Large
# 49914                       Zhong shan Broad-Ocean Motor  Large
# 49915  Zhongfu Straits (Pingtan) Development Company ...  Large
# 49916                                      Zhongjin Gold  Large
# 49917                                    ZHONGMIN ENERGY  Large
# 49918                          Zhongsheng Group Holdings  Large
# 49919                          Zhongtian Financial Group  Large
# 49920                            ZHONGYUAN SPECIAL STEEL  Large
# 49921                                  Zhongyuan Union    Large
# 49922                          Zhou Hei Ya International    MNE
# 49923                               Zhuzhou Kibing Group  Large
# 49924                             ZHUZHOU TIANQIAO CRANE  Large
# 49925              Zhuzhou Times New Material Technology  Large
# 49926                           Zig Sheng Ind. Co., Ltd.    MNE
# 49927                                 Zijin Mining Group  Large
# 49928                                Zimmite Taiwan Ltd.  Large
# 49929                                        Ziraat Bank  Large
# 49930                                   Zodiac Aerospace    MNE
# 49931                                             Zoetis    MNE
# 49932                                              Zofri  Large
# 49933                                        Zoltek Zrt.  Large
# 49934                                 Zona Franca Bogotá    SME
# 49935                        Zona Franca de Barranquilla  Large
# 49936     Zoomlion Heavy Industry Science And Technology  Large
# 49937                                         Zoopla plc  Large
# 49938                                      Zorlu Holding  Large
# 49939                                                ZSE    MNE
# 49940                                    ZTE Corporation  Large
# 49941                          Zuellig Family Foundation    SME
# 49942                               Zürcher Kantonalbank  Large
# 49943                             Zurich Insurance Group  Large
# 49944                                  Zwack Unicum Nyrt  Large
#
#                            Sector  \
# 49900          Financial Services
# 49901               Conglomerates
# 49902                   Equipment
# 49903                      Energy
# 49904                       Other
# 49905                       Other
# 49906      Construction Materials
# 49907                   Chemicals
# 49908                       Other
# 49909                Construction
# 49910         Technology Hardware
# 49911                       Other
# 49943                            No                                      No
# 49944                            No                                      No
#
#       Assurance Standard: national (sustainability) Materiality Matters Check  \
# 49900                                            No                       NaN
# 49901                                            No                       NaN
# 49902                                            No                       NaN
# 49903                                            No                       NaN
# 49904                                            No                       NaN
# 49905                                            No                       NaN
# 49906                                            No                       NaN
# 49907                                            No                       NaN
# 49908                                            No                       NaN
# 49909                                            No                       NaN
# 49910                                            No                       NaN
# 49911                                            No                       NaN
# 49912                                            No                       NaN
# 49913                                            No                       NaN
# 49914                                            No                       NaN
# 49915                                            No                       NaN
# 49916                                            No                       NaN
# 49917                                            No                       NaN
# 49918                                           Yes                       NaN
# 49919                                            No                       NaN
# 49920                                            No                       NaN
# 49921                                            No                       NaN
# 49922                                           Yes                       NaN
# 49923                                            No                       NaN
# 49924                                            No                       NaN
# 49925                                            No                       NaN
# 49926                                            No                       NaN
# 49927                                            No                       NaN
# 49928                                            No                       NaN
# 49929                                            No                       NaN
# 49930                                            No                       NaN
# 49931                                            No                       NaN
# 49932                                            No                       NaN
# 49933                                            No                       NaN
# 49934                                            No                       NaN
# 49935                                            No                       NaN
# 49936                                            No                       NaN
# 49937                                            No                       NaN
# 49938                                            No                       NaN
# 49939                                            No                       NaN
# 49940                                            No                       NaN
# 49941                                            No                       NaN
# 49942                                            No                       NaN
# 49943                                            No                       NaN
# 49944                                            No                       NaN
#
#                            GRI Service Featured Report?   OS GOLD Community  \
# 49900                              NaN               No  NaN             No
# 49901                              NaN               No  NaN             No
# 49902                              NaN               No  NaN             No
# 49903                              NaN               No  NaN             No
# 49904                              NaN               No  NaN             No
# 49905                              NaN               No  NaN             No
# 49906                              NaN               No  NaN             No
# 49907                              NaN               No  NaN             No
# 49908                              NaN               No  NaN             No
# 49909                              NaN               No  NaN             No
# 49910                              NaN               No  NaN             No
# 49911                              NaN               No  NaN             No
# 49912                              NaN               No  NaN             No
# 49913                              NaN               No  NaN             No
# 49914                              NaN               No  NaN             No
# 49915                              NaN               No  NaN             No
# 49916                              NaN               No  NaN             No
# 49917                              NaN               No  NaN             No
# 49918                              NaN               No  NaN             No
# 49919                              NaN               No  NaN             No
# 49920                              NaN               No  NaN             No
# 49921                              NaN               No  NaN             No
# 49922                              NaN               No  NaN             No
# 49923                              NaN               No  NaN             No
# 49924                              NaN               No  NaN             No
# 49925                              NaN               No  NaN             No
# 49926                              NaN               No  NaN             No
# 49927                              NaN               No  NaN             No
# 49928                              NaN               No  NaN             No
# 49929                              NaN               No  NaN             No
# 49930                              NaN               No  NaN             No
# 49931                              NaN               No  NaN             No
# 49932                              NaN               No  NaN             No
# 49933                              NaN               No  NaN             No
# 49934                              NaN               No  NaN             No
# 49935  Materiality Disclosures Service               No  NaN             No
# 49936                              NaN               No  NaN             No
# 49937                              NaN               No  NaN             No
# 49938                              NaN               No  NaN             No
# 49939                              NaN               No  NaN             No
# 49940                              NaN               No  NaN             No
# 49941  Materiality Disclosures Service               No  NaN             No
# 49942  Materiality Disclosures Service               No  NaN             No
# 49943                              NaN               No  NaN             No
# 49944                              NaN               No  NaN             No
#
#       SDGs
# 49900  NaN
# 49901   No
# 49902   No
# 49903   No
# 49904   No
# 49905  NaN
# 49906   No
# 49907  NaN
# 49908  NaN
# 49909   No
# 49910  Yes
# 49911  NaN
# 49912  NaN
# 49913  NaN
# 49914  NaN
# 49915  NaN
# 49916  NaN
# 49917  NaN
# 49918  NaN
# 49919  NaN
# 49920  NaN
# 49921  NaN
# 49922  NaN
# 49923  NaN
# 49924  NaN
# 49925  NaN
# 49926  Yes
# 49927   No
# 49928   No
# 49929  NaN
# 49930  NaN
# 49931   No
# 49932   No
# 49933   No
# 49934  NaN
# 49935   No
# 49936  NaN
# 49937  NaN
# 49938  NaN
# 49939  NaN
# 49940   No
# 49941   No
# 49942   No
# 49943  NaN
# 49944  Yes
#
# [45 rows x 43 columns]

# %%
df1=pd.read_excel('C://Users//chowd//Downloads//Thesis//myFileName.xlsx')

# %%
df1
# Out:
#         Country                           Name  Publication.Year  \
# 0       Albania  Albania Mobile Communications            2013.0
# 1       Andorra                 Crèdit Andorrà            2011.0
# 2       Andorra                 Crèdit Andorrà            2012.0
# 3       Andorra                 Crèdit Andorrà            2013.0
# 4       Andorra                 Crèdit Andorrà            2017.0
# ...         ...                            ...               ...
# 13099  Zimbabwe                       Padenga             2016.0
# 13100  Zimbabwe                       Padenga             2017.0
# 13101  Zimbabwe             Simbisa Brands Ltd            2017.0
# 13102  Zimbabwe               Turnall Holdings            2013.0
# 13103  Zimbabwe               Turnall Holdings            2015.0
#
#                                       Report.PDF.Address   Size  \
# 0      https://www.telekom.com.al/reports/english/CR_...  Large
# 1      https://www.creditandorragroup.com/sites/defau...  Large
# 2      https://www.creditandorragroup.com/sites/defau...  Large
# 3      https://www.creditandorragroup.com/sites/defau...  Large
# 4      https://www.creditandorragroup.com/sites/defau...  Large
# ...                                                  ...    ...
# 13099  http://www.padenga.com/download/annual_reports...    SME
# 13100  http://www.padenga.com/download/annual_reports...    SME
# 13101  http://www.simbisabrands.com/wp-content/upload...  Large
# 13102  http://b2icontent.irpass.cc/2037%2F145928.pdf?...  Large
# 13103  http://www.turnall.co.zw/download-files/financ...  Large
#
#                            Sector      Country.Status  Region Date.Added  \
# 0              Telecommunications           DAC-UMICT  Europe 2016-11-01
# 1              Financial Services  Non-OECD / Non-DAC  Europe 2015-06-10
# 2              Financial Services  Non-OECD / Non-DAC  Europe 2015-06-10
# 3              Financial Services  Non-OECD / Non-DAC  Europe 2015-06-10
# 4              Financial Services  Non-OECD / Non-DAC  Europe 2017-07-10
# ...                           ...                 ...     ...        ...
# 13099        Textiles and Apparel            DAC-OLIC  Africa 2017-02-16
# 13100        Textiles and Apparel            DAC-OLIC  Africa 2018-02-09
# 13101  Food and Beverage Products            DAC-OLIC  Africa 2017-11-14
# 13102      Construction Materials            DAC-OLIC  Africa 2013-05-21
# 13103      Construction Materials            DAC-OLIC  Africa 2017-02-15
#
#                                              Title  ...  \
# 0         AMC Corporate Responsibility 2012 Report  ...
# 1      Corporate Social Responsibility Report 2011  ...
# 2      Corporate Social Responsibility Report 2012  ...
# 3      Corporate Social Responsibility Report 2013  ...
# 4      Corporate Social Responsibility Report 2016  ...
# ...                                            ...  ...
# 13099                           Annual Report 2015  ...
# 13100                           Annual Report 2016  ...
# 13101        Simbisa Brands Ltd Annual Report 2017  ...
# 13102          Turnall Holdings Annual report 2012  ...
# 13103                Integrated Annual Report 2014  ...
#
#       Materiality.Matters.Check GRI.Service GOLD.Community SDGs  \
# 0                           NaN         NaN            NaN  NaN
# 1                           NaN         NaN            NaN  NaN
# 2                           NaN         NaN            NaN  NaN
# 3                           NaN         NaN            NaN  NaN
# 4                           NaN         NaN             No  Yes
# ...                         ...         ...            ...  ...
# 13099                       NaN         NaN             No  NaN
# 13100                       NaN         NaN             No  NaN
# 13101                       NaN         NaN             No   No
# 13102                       NaN         NaN            NaN  NaN
# 13103                       NaN         NaN             No  NaN
#
#                                    file pdf_language english_non_english  \
# 0      AlbaniaMobileCommunications_2013      english             english
# 1                    CrèditAndorrà_2011      english             english
# 2                    CrèditAndorrà_2012      english             english
# 3                    CrèditAndorrà_2013      english             english
# 4                    CrèditAndorrà_2017      english             english
# ...                                 ...          ...                 ...
# 13099                      Padenga_2016      english             english
# 13100                      Padenga_2017      english             english
# 13101             SimbisaBrandsLtd_2017      english             english
# 13102              TurnallHoldings_2013      english             english
# 13103              TurnallHoldings_2015      english             english
#
#       Legal origin.x Legal origin.y Type.Binary
# 0             French         French         GRI
# 1             French         French         GRI
# 2             French         French         GRI
# 3             French         French         GRI
# 4             French         French         GRI
# ...              ...            ...         ...
# 13099        English        English   Non - GRI
# 13100        English        English   Non - GRI
# 13101        English        English         GRI
# 13102        English        English         GRI
# 13103        English        English         GRI
#
# [13104 rows x 44 columns]

# %%
df1['Publication Year']=df1['Publication.Year']

# %%
df2=df1[['Name','Publication Year','Report.PDF.Address']]

# %%
df2
# Out:
#                                 Name  Publication Year  \
# 0      Albania Mobile Communications            2013.0
# 1                     Crèdit Andorrà            2011.0
# 2                     Crèdit Andorrà            2012.0
# 3                     Crèdit Andorrà            2013.0
# 4                     Crèdit Andorrà            2017.0
# ...                              ...               ...
# 13099                       Padenga             2016.0
# 13100                       Padenga             2017.0
# 13101             Simbisa Brands Ltd            2017.0
# 13102               Turnall Holdings            2013.0
# 13103               Turnall Holdings            2015.0
#
#                                       Report.PDF.Address
# 0      https://www.telekom.com.al/reports/english/CR_...
# 1      https://www.creditandorragroup.com/sites/defau...
# 2      https://www.creditandorragroup.com/sites/defau...
# 3      https://www.creditandorragroup.com/sites/defau...
# 4      https://www.creditandorragroup.com/sites/defau...
# ...                                                  ...
# 13099  http://www.padenga.com/download/annual_reports...
# 13100  http://www.padenga.com/download/annual_reports...
# 13101  http://www.simbisabrands.com/wp-content/upload...
# 13102  http://b2icontent.irpass.cc/2037%2F145928.pdf?...
# 13103  http://www.turnall.co.zw/download-files/financ...
#
# [13104 rows x 3 columns]

# %%
kb=df2.merge(mdf, on = ('Name','Publication Year'),how='outer')

# %%
kb
# Out:
#                                 Name  Publication Year  \
# 0      Albania Mobile Communications            2013.0
# 1                     Crèdit Andorrà            2011.0
# 2                     Crèdit Andorrà            2012.0
# 3                     Crèdit Andorrà            2013.0
# 4                     Crèdit Andorrà            2017.0
# ...                              ...               ...
# 51034                ZTE Corporation            2017.0
# 51035      Zuellig Family Foundation            2017.0
# 51036           Zürcher Kantonalbank            2017.0
# 51037         Zurich Insurance Group            2017.0
# 51038              Zwack Unicum Nyrt            2017.0
#
#                                       Report.PDF.Address   Size  \
# 0      https://www.telekom.com.al/reports/english/CR_...  Large
# 1      https://www.creditandorragroup.com/sites/defau...  Large
# 2      https://www.creditandorragroup.com/sites/defau...  Large
# 3      https://www.creditandorragroup.com/sites/defau...  Large
# 4      https://www.creditandorragroup.com/sites/defau...  Large
# ...                                                  ...    ...
# 51034                                                NaN  Large
# 51035                                                NaN    SME
# 51036                                                NaN  Large
# 51037                                                NaN  Large
# 51038                                                NaN  Large
#
#                            Sector         Country      Country Status  Region  \
# 0              Telecommunications         Albania           DAC-UMICT  Europe
# 1              Financial Services         Andorra  Non-OECD / Non-DAC  Europe
# 2              Financial Services         Andorra  Non-OECD / Non-DAC  Europe
# 3              Financial Services         Andorra  Non-OECD / Non-DAC  Europe
# 4              Financial Services         Andorra  Non-OECD / Non-DAC  Europe
# ...                           ...             ...                 ...     ...
# 51034         Technology Hardware  Mainland China           DAC-UMICT    Asia
# 51035       Non-Profit / Services     Philippines           DAC-LMICT    Asia
# 51036          Financial Services     Switzerland                OECD  Europe
# 51037          Financial Services     Switzerland                OECD  Europe
# 51038  Food and Beverage Products         Hungary                OECD  Europe
#
#       Date Added                                          Title  ...  \
# 0      1-11-2016       AMC Corporate Responsibility 2012 Report  ...
# 1      10-6-2015    Corporate Social Responsibility Report 2011  ...
# 2      10-6-2015    Corporate Social Responsibility Report 2012  ...
# 3      10-6-2015    Corporate Social Responsibility Report 2013  ...
# 4      10-7-2017    Corporate Social Responsibility Report 2016  ...
# ...          ...                                            ...  ...
# 51034   6-6-2017                     Sustainability Report 2016  ...
# 51035  25-9-2018          Annual and Sustainability Report 2016  ...
# 51036  5-10-2017  Nachhaltigkeitsbericht zum Geschäftsjahr 2016  ...
# 51037  25-4-2017       2016 Corporate Responsibility Highlights  ...
# 51038  23-2-2020                     Sustainability Report 2017  ...
#
#       Assurance Standard: AA1000 AS Assurance Stanadard: ISAE3000  \
# 0                                No                            No
# 1                               NaN                           NaN
# 2                                No                            No
# 3                                No                            No
# 4                                No                            No
# ...                             ...                           ...
# 51034                            No                            No
# 51035                           Yes                            No
# 51036                            No                            No
# 51037                            No                            No
# 51038                            No                            No
#
#       Assurance Standard: national (general)  \
# 0                                         No
# 1                                        NaN
# 2                                         No
# 3                                         No
# 4                                         No
# ...                                      ...
# 51034                                     No
# 51035                                     No
# 51036                                     No
# 51037                                     No
# 51038                                     No
#
#        Assurance Standard: national (sustainability)  \
# 0                                                 No
# 1                                                NaN
# 2                                                 No
# 3                                                 No
# 4                                                 No
# ...                                              ...
# 51034                                             No
# 51035                                             No
# 51036                                             No
# 51037                                             No
# 51038                                             No
#
#       Materiality Matters Check                      GRI Service  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3                           NaN                              NaN
# 4                           NaN                              NaN
# ...                         ...                              ...
# 51034                       NaN                              NaN
# 51035                       NaN  Materiality Disclosures Service
# 51036                       NaN  Materiality Disclosures Service
# 51037                       NaN                              NaN
# 51038                       NaN                              NaN
#
#       Featured Report?   OS GOLD Community SDGs
# 0                  NaN  NaN            NaN  NaN
# 1                  NaN  NaN            NaN  NaN
# 2                  NaN  NaN            NaN  NaN
# 3                  NaN  NaN            NaN  NaN
# 4                   No  NaN             No  Yes
# ...                ...  ...            ...  ...
# 51034               No  NaN             No   No
# 51035               No  NaN             No   No
# 51036               No  NaN             No   No
# 51037               No  NaN             No  NaN
# 51038               No  NaN             No  Yes
#
# [51039 rows x 44 columns]

# %%
kb['Report_Pdf_Address']=kb['Report Pdf Address']
kb['Report_PDF_Address_1']=kb['Report.PDF.Address']

# %%
kb["Unique"] = kb["Report_Pdf_Address"][~kb["Report_Pdf_Address"].isin(kb["Report_PDF_Address_1"])]
#items_data['col_def'] = items_data['col_a'][~items_data['col_a'].isin(items_data['col_b'])]

# %%
kb["Report_Pdf_Address"] = kb["Report_Pdf_Address"].fillna(0)

# %%
kb.loc[kb.Report_Pdf_Address == 0 , 'Unique'] = kb["Report_PDF_Address_1"]

# %%
kb["Unique"].isnull().sum()
# Out:
# 24415

# %%
kb["Report Pdf Address"].isnull().sum()
# Out:
# 12100

# %%
kb[["Report_Pdf_Address","Unique","Report_PDF_Address_1"]].head(60)
# Out:
#                                    Report_Pdf_Address  \
# 0   https://www.telekom.com.al/reports/english/CR_...
# 1   https://www.creditandorragroup.com/sites/defau...
# 2   https://www.creditandorragroup.com/sites/defau...
# 3   https://www.creditandorragroup.com/sites/defau...
# 4   https://www.creditandorragroup.com/sites/defau...
# 5   https://www.morabanc.ad/app/uploads/informe201...
# 6   https://www.morabanc.ad/app/uploads/INFORME-AN...
# 7   http://www.bodiva.ao/files/relatorio-contas/re...
# 8   http://www.bodiva.ao/files/relatorio-contas/re...
# 9   http://www.bp.com/content/dam/bp/pdf/sustainab...
# 10  http://www.bp.com/content/dam/bp-country/en_za...
# 11  https://www.bp.com/content/dam/bp/en/corporate...
# 12  http://www.bancoprestigio.com/0064/Relatorio-e...
# 13  http://www.bancoprestigio.com/0064/Relatorio-e...
# 14  http://www.bancosol.ao/upl/%7B5779b806-472b-4a...
# 15  http://www.bancosol.ao/upl/%7B05a86b6e-7639-4c...
# 16  http://www.bci.ao/Portals/1/Documentos/BCI-Rel...
# 17  http://www.bci.ao/Portals/1/Documentos/RELATOR...
# 18  http://odebrecht.com/sites/default/files/rsode...
# 19  https://www.standardbank.co.ao/standimg/Angola...
# 20  http://www.innovacionentuvida.com.ar/sustentab...
# 21  http://www.innovacionentuvida.com.ar/sustentab...
# 22  http://www.innovacionentuvida.com.ar/sustentab...
# 23  http://www.acindar.com.ar/es/sites/default/fil...
# 24  https://www.acindar.com.ar/es/sites/default/fi...
# 25  http://www.adecco.com.ar/wp-content/uploads/su...
# 26  http://www.aa2000.com.ar/pdf/AA2000_Reporte_Su...
# 27  http://www.aysa.com.ar/Media/archivos/537/RS_A...
# 28  http://www.aysa.com.ar/Media/archivos/698/RSE2...
# 29  http://www.aysa.com.ar/Media/contenidos/913/Ay...
# 30  https://www.allianz.com.ar/sites/default/files...
# 31  http://www.andreani.com/Uploads/Documentos/RSE...
# 32  http://www.andreani.com/home/Reporte%20de%20Su...
# 33                                                  0
# 34                                                  0
# 35                                                  0
# 
# 26  http://www.aa2000.com.ar/pdf/AA2000_Reporte_Su...
# 27  http://www.aysa.com.ar/Media/archivos/537/RS_A...
# 28  http://www.aysa.com.ar/Media/archivos/698/RSE2...
# 29  http://www.aysa.com.ar/Media/contenidos/913/Ay...
# 30  https://www.allianz.com.ar/sites/default/files...
# 31  http://www.andreani.com/Uploads/Documentos/RSE...
# 32  http://www.andreani.com/home/Reporte%20de%20Su...
# 33  http://www.arcosdorados.com/attached/editorial...
# 34  http://portal.acabase.com.ar/Balances/BALANCES...
# 35  http://portal.acabase.com.ar/Balances/ACA_MEMO...
# 36  https://www.bbvafrances.com.ar/fbin/mult/IARC_...
# 37  https://www.bbvafrances.com.ar/fbin/mult/IARC_...
# 38  https://www.bbvafrances.com.ar/fbin/mult/IARC2...
# 39  http://www.hipotecario.com.ar/media/pdf/Report...
# 40  http://www.hipotecario.com.ar/media/MemoriaDig...
# 41  http://www.hipotecario.com.ar/media/pdf/Report...
# 42  http://www.hipotecario.com.ar/media/pdf/report...
# 43  http://www.hipotecario.com.ar/media/pdf/Report...
# 44  https://www.hipotecario.com.ar/media/pdf/Repor...
# 45  http://www.bna.com.ar/download/InformedeRespon...
# 46  http://www.bancopatagonia.com/institucional/do...
# 47  http://www.bancopatagonia.com/institucional/do...
# 48  http://www.bancopatagonia.com/institucional/do...
# 49  http://www.bancopatagonia.com/institucional/do...
# 50  http://www.bancopatagonia.com/institucional/do...
# 51  https://www.unglobalcompact.org/system/attachm...
# 52  https://www.santanderrio.com.ar/banco/wcm/conn...
# 53  https://www.unglobalcompact.org/system/attachm...
# 54  http://barricksudamerica.com/barrick/site/arti...
# 55  http://contenido.cablevisionfibertel.com.ar/ga...
# 56  http://www.carrefour.com.ar/media/folletos/boo...
# 57  http://www.agsustentable.com/reportes/Casino_S...
# 58  http://www.casinosantafe.com.ar/wp-content/upl...
# 59  http://www.casinosantafe.com.ar/wp-content/upl...

# %%
kb['Unique'].nunique()
# Out:
# 26283

# %% [markdown]
# kb = kb.drop(kb[kb.Report_Pdf_Address == 0].index)

# %%
kb
# Out:
#                                 Name  Publication Year  \
# 0      Albania Mobile Communications            2013.0
# 1                     Crèdit Andorrà            2011.0
# 2                     Crèdit Andorrà            2012.0
# 3                     Crèdit Andorrà            2013.0
# 4                     Crèdit Andorrà            2017.0
# ...                              ...               ...
# 51034                ZTE Corporation            2017.0
# 51035      Zuellig Family Foundation            2017.0
# 51036           Zürcher Kantonalbank            2017.0
# 51037         Zurich Insurance Group            2017.0
# 51038              Zwack Unicum Nyrt            2017.0
#
#                                       Report.PDF.Address   Size  \
# 0      https://www.telekom.com.al/reports/english/CR_...  Large
# 1      https://www.creditandorragroup.com/sites/defau...  Large
# 2      https://www.creditandorragroup.com/sites/defau...  Large
# 3      https://www.creditandorragroup.com/sites/defau...  Large
# 4      https://www.creditandorragroup.com/sites/defau...  Large
# ...                                                  ...    ...
# 51034                                                NaN  Large
# 51035                                                NaN    SME
# 51036                                                NaN  Large
# 51037                                                NaN  Large
# 51038                                                NaN  Large
#
#                            Sector         Country      Country Status  Region  \
# 0              Telecommunications         Albania           DAC-UMICT  Europe
# 1              Financial Services         Andorra  Non-OECD / Non-DAC  Europe
# 2              Financial Services         Andorra  Non-OECD / Non-DAC  Europe
# 3              Financial Services         Andorra  Non-OECD / Non-DAC  Europe
# 4              Financial Services         Andorra  Non-OECD / Non-DAC  Europe
# ...                           ...             ...                 ...     ...
# 51034         Technology Hardware  Mainland China           DAC-UMICT    Asia
# 51035       Non-Profit / Services     Philippines           DAC-LMICT    Asia
# 51036          Financial Services     Switzerland                OECD  Europe
# 51037          Financial Services     Switzerland                OECD  Europe
# 51038  Food and Beverage Products         Hungary                OECD  Europe
#
#       Date Added                                          Title  ...  \
# 0      1-11-2016       AMC Corporate Responsibility 2012 Report  ...
# 1      10-6-2015    Corporate Social Responsibility Report 2011  ...
# 2      10-6-2015    Corporate Social Responsibility Report 2012  ...
# 3      10-6-2015    Corporate Social Responsibility Report 2013  ...
# 4      10-7-2017    Corporate Social Responsibility Report 2016  ...
# ...          ...                                            ...  ...
# 51034   6-6-2017                     Sustainability Report 2016  ...
# 51035  25-9-2018          Annual and Sustainability Report 2016  ...
# 51036  5-10-2017  Nachhaltigkeitsbericht zum Geschäftsjahr 2016  ...
# 51037  25-4-2017       2016 Corporate Responsibility Highlights  ...
# 51038  23-2-2020                     Sustainability Report 2017  ...
#
#       Assurance Standard: national (sustainability) Materiality Matters Check  \
# 0                                                No                       NaN
# 1                                               NaN                       NaN
# 2                                                No                       NaN
# 3                                                No                       NaN
# 4                                                No                       NaN
# ...                                             ...                       ...
# 51034                                            No                       NaN
# 51035                                            No                       NaN
# 51036                                            No                       NaN
# 51037                                            No                       NaN
# 51038                                            No                       NaN
#
#                            GRI Service  Featured Report?   OS GOLD Community  \
# 0                                  NaN               NaN  NaN            NaN
# 1                                  NaN               NaN  NaN            NaN
# 2                                  NaN               NaN  NaN            NaN
# 3                                  NaN               NaN  NaN            NaN
# 4                                  NaN                No  NaN             No
# ...                                ...               ...  ...            ...
# 51034                              NaN                No  NaN             No
# 51035  Materiality Disclosures Service                No  NaN             No
# 51036  Materiality Disclosures Service                No  NaN             No
# 51037                              NaN                No  NaN             No
# 51038                              NaN                No  NaN             No
#
#       SDGs                                 Report_Pdf_Address  \
# 0      NaN  https://www.telekom.com.al/reports/english/CR_...
# 1      NaN  https://www.creditandorragroup.com/sites/defau...
# 2      NaN  https://www.creditandorragroup.com/sites/defau...
# 3      NaN  https://www.creditandorragroup.com/sites/defau...
# 4      Yes  https://www.creditandorragroup.com/sites/defau...
# ...    ...                                                ...
# 51034   No  http://pdf.dfcfw.com/pdf/H2_AN2017032304313170...
# 51035   No                                                  0
# 51036   No  https://www.zkb.ch/media/pub/coporate/jahresbe...
# 51037  NaN                                                  0
# 51038  Yes  https://zwackunicum.hu/files/cegunk_fenntartha...
#
#                                     Report_PDF_Address_1  \
# 0      https://www.telekom.com.al/reports/english/CR_...
# 1      https://www.creditandorragroup.com/sites/defau...
# 2      https://www.creditandorragroup.com/sites/defau...
# 3      https://www.creditandorragroup.com/sites/defau...
# 4      https://www.creditandorragroup.com/sites/defau...
# ...                                                  ...
# 51034                                                NaN
# 51035                                                NaN
# 51036                                                NaN
# 51037                                                NaN
# 51038                                                NaN
#
#                                                   Unique
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 51034  http://pdf.dfcfw.com/pdf/H2_AN2017032304313170...
# 51035                                                NaN
# 51036  https://www.zkb.ch/media/pub/coporate/jahresbe...
# 51037                                                NaN
# 51038  https://zwackunicum.hu/files/cegunk_fenntartha...
#
# [51039 rows x 47 columns]

# %%
options = webdriver.ChromeOptions()
prefs = {"download.default_directory" : "C:\\Users\\chowd\\Downloads\\Thesis\\Thesis_files_download"}
options.add_experimental_option("prefs",prefs)
prefs = {"network.http.response.timeout":30}
options.add_experimental_option("prefs", prefs)
options.add_experimental_option("useAutomationExtension", False)
options.add_experimental_option("excludeSwitches",["enable-automation"])
driver_path = 'chromedriver'
from selenium.common.exceptions import StaleElementReferenceException

# %%
ll = kb[kb['Publication Year']==2013]
for i in ll['Unique'].dropna().unique():
            driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)
            driver.delete_all_cookies()    
            driver.maximize_window()
            driver.get(i)
            time.sleep(5)
            mouse = Controller()
            mouse.position = (320, 72)
            time.sleep(10)
            mouse.move(850, 30)
            time.sleep(5)
            mouse.press(Button.left)
            time.sleep(1)
            mouse.release(Button.left)
            time.sleep(5)
            mouse = Controller()
            mouse.position = (320, 72)
            time.sleep(5)
            mouse.move(150, 380)
            time.sleep(5)
            mouse.press(Button.left)
            time.sleep(1)
            mouse.release(Button.left)
            time.sleep(10)
            driver.close()
# Out:
# <ipython-input-23-f2517d043e28>:3: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-f2517d043e28> in <module>
#       8             mouse = Controller()
#       9             mouse.position = (320, 72)
# ---> 10             time.sleep(10)
#      11             mouse.move(850, 30)
#      12             time.sleep(5)
#
# KeyboardInterrupt:

# %% [markdown]
# income_statement_files = glob.glob('C:/Users/citco/Downloads/Income Statement_Annual_As Originally Reported*.xls')
# inc_statement = max(income_statement_files, key=os.path.getctime)
# inc_statement_df = pd.read_excel(inc_statement)

# %%
ll
# Out:
#                                 Name  Publication Year  \
# 0      Albania Mobile Communications            2013.0
# 3                     Crèdit Andorrà            2013.0
# 20                      3M Argentina            2013.0
# 31                          Andreani            2013.0
# 40                 Banco Hipotecario            2013.0
# ...                              ...               ...
# 32734             Zorlu Energy Group            2013.0
# 32735                            ZSE            2013.0
# 32736           Zürcher Kantonalbank            2013.0
# 32737       Zurich Insurance Company            2013.0
# 32738              Zwack Unicum Nyrt            2013.0
#
#                                       Report.PDF.Address   Size  \
# 0      https://www.telekom.com.al/reports/english/CR_...  Large
# 3      https://www.creditandorragroup.com/sites/defau...  Large
# 20     http://www.innovacionentuvida.com.ar/sustentab...  Large
# 31     http://www.andreani.com/Uploads/Documentos/RSE...  Large
# 40     http://www.hipotecario.com.ar/media/MemoriaDig...  Large
# ...                                                  ...    ...
# 32734                                                NaN  Large
# 32735                                                NaN    MNE
# 32736                                                NaN  Large
# 32737                                                NaN  Large
# 32738                                                NaN  Large
#
#                            Sector          Country      Country Status  \
# 0              Telecommunications          Albania           DAC-UMICT
# 3              Financial Services          Andorra  Non-OECD / Non-DAC
# 20                  Conglomerates        Argentina           DAC-UMICT
# 31                      Logistics        Argentina           DAC-UMICT
# 40             Financial Services        Argentina           DAC-UMICT
# ...                           ...              ...                 ...
# 32734            Energy Utilities           Turkey           DAC-UMICT
# 32735                      Energy  Slovak Republic                OECD
# 32736          Financial Services      Switzerland                OECD
# 32737          Financial Services     South Africa           DAC-UMICT
# 32738  Food and Beverage Products          Hungary                OECD
#
#                               Region Date Added  \
# 0                             Europe  1-11-2016
# 3                             Europe  10-6-2015
# 20     Latin America & the Caribbean  14-4-2014
# 31     Latin America & the Caribbean   4-9-2014
# 40     Latin America & the Caribbean  21-2-2014
# ...                              ...        ...
# 32734                           Asia  15-8-2014
# 32735                         Europe  2-12-2015
# 32736                         Europe  19-4-2013
# 32737                         Africa   6-3-2015
# 32738                         Europe  11-4-2014
#
#                                              Title  ...  \
# 0         AMC Corporate Responsibility 2012 Report  ...
# 3      Corporate Social Responsibility Report 2013  ...
# 20                 Reporte de Sustentabilidad 2012  ...
# 31          Reporte de Sustentabilidad 2011 - 2012  ...
# 40                 Reporte de Sustentabilidad 2012  ...
# ...                                            ...  ...
# 32734                           Annual Report 2012  ...
# 32735          Správa o zodpovednom podnikání 2012  ...
# 32736                  Nachhaltigkeitsbericht 2012  ...
# 32737                       Integrated Report 2012  ...
# 32738                   2013 Sustainability Report  ...
#
#       Assurance Standard: national (sustainability) Materiality Matters Check  \
# 0                                                No                       NaN
# 3                                                No                       NaN
# 20                                               No                       NaN
# 31                                               No                       NaN
# 40                                               No                       NaN
# ...                                             ...                       ...
# 32734                                            No                       NaN
# 32735                                            No                       NaN
# 32736                                            No                       NaN
# 32737                                            No                       NaN
# 32738                                            No                       NaN
#
#       GRI Service  Featured Report?   OS GOLD Community SDGs  \
# 0             NaN               NaN  NaN            NaN  NaN
# 3             NaN               NaN  NaN            NaN  NaN
# 20            NaN               NaN  NaN            NaN  NaN
# 31            NaN               NaN  NaN            NaN  NaN
# 40            NaN               NaN  NaN            NaN  NaN
# ...           ...               ...  ...            ...  ...
# 32734         NaN               NaN  NaN            NaN  NaN
# 32735         NaN               NaN  NaN            NaN  NaN
# 32736         NaN               NaN  NaN            NaN  NaN
# 32737         NaN               NaN  NaN            NaN  NaN
# 32738         NaN               NaN  NaN            NaN  NaN
#
#                                       Report_Pdf_Address  \
# 0      https://www.telekom.com.al/reports/english/CR_...
# 3      https://www.creditandorragroup.com/sites/defau...
# 20     http://www.innovacionentuvida.com.ar/sustentab...
# 31     http://www.andreani.com/Uploads/Documentos/RSE...
# 40     http://www.hipotecario.com.ar/media/MemoriaDig...
# ...                                                  ...
# 32734    http://www.zoren.com.tr/FILES/ZRE_FRAE_2012.pdf
# 32735                                                  0
# 32736  http://www.zkb.ch/etc/ml/repository/textdokume...
# 32737  http://www.zurich.co.za/wp-content/uploads/pdf...
# 32738  http://www.zwack.hu/files/cegunk_fenntarthatos...
#
#                                     Report_PDF_Address_1  \
# 0      https://www.telekom.com.al/reports/english/CR_...
# 3      https://www.creditandorragroup.com/sites/defau...
# 20     http://www.innovacionentuvida.com.ar/sustentab...
# 31     http://www.andreani.com/Uploads/Documentos/RSE...
# 40     http://www.hipotecario.com.ar/media/MemoriaDig...
# ...                                                  ...
# 32734                                                NaN
# 32735                                                NaN
# 32736                                                NaN
# 32737                                                NaN
# 32738                                                NaN
#
#                                                   Unique
# 0                                                    NaN
# 3                                                    NaN
# 20                                                   NaN
# 31                                                   NaN
# 40                                                   NaN
# ...                                                  ...
# 32734    http://www.zoren.com.tr/FILES/ZRE_FRAE_2012.pdf
# 32735                                                NaN
# 32736  http://www.zkb.ch/etc/ml/repository/textdokume...
# 32737  http://www.zurich.co.za/wp-content/uploads/pdf...
# 32738  http://www.zwack.hu/files/cegunk_fenntarthatos...
#
# [5414 rows x 47 columns]

# %% [markdown]
# f2013 = []

# %% [markdown]
# f2014=[]

# %%
ll = kb[kb['Publication Year']==2014]
for i in ll['Unique'].dropna().unique()[1660:5000]:
    ty = ll[ll['Unique']==i]
    for j in ty['Name']:
        f2014.append((i,j))
        
        driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)
        driver.delete_all_cookies()    
        driver.maximize_window()
        
        try:
            driver.set_page_load_timeout(30)
            driver.get(i)
            mouse = Controller()
            mouse.position = (320, 72)
            time.sleep(90)
            mouse.move(1450, 50)
            time.sleep(5)
            mouse.press(Button.left)
            time.sleep(1)
            mouse.release(Button.left)
            time.sleep(5)
            pyautogui.typewrite('{}_2014'.format(j))
            time.sleep(5)
            pyautogui.hotkey('enter')
            time.sleep(10)
            driver.close()
        except:
            isrunning = 0
            driver.close()
# Out:
# <ipython-input-243-f49827318dcf>:7: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=driver_path, chrome_options=options)
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# <ipython-input-243-f49827318dcf> in <module>
#      12             driver.set_page_load_timeout(30)
# ---> 13             driver.get(i)
#      14             mouse = Controller()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 28.382
#   (Session info: chrome=89.0.4389.114)
#
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-243-f49827318dcf> in <module>
#      28         except:
#      29             isrunning = 0
# ---> 30             driver.close()
#      31
#      32
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: unknown error: failed to close window in 20 seconds
#   (Session info: chrome=89.0.4389.114)

# %%
f2014
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ff37e39e57f> in <module>
# ----> 1 f2014
#
# NameError: name 'f2014' is not defined

# %%
df_f2014=pd.DataFrame(f2014)

# %%
df_f2014.columns = ['URL', 'Name']

# %%
df_f2014[df_f2014.duplicated()]
# Out:
#                                                    URL  \
# 19   http://bisa.com/memoriaRSE/memoria_RSE_2012-20...
# 20   http://amaggi.com.br/wp-content/uploads/2014/0...
# 28   http://www.capacero.cl/pdf/cap_reporte_sustent...
# 29   http://www.capacero.cl/pdf/cap_reporte_sustent...
# 30   http://www.capacero.cl/pdf/cap_reporte_sustent...
# 597  http://www.adfd.ae/media/publications/Annual%2...
# 598  http://www.taqaglobal.com/~/media/Files/T/Taqa...
# 838  http://www.cofco.com/uploadfiles/cms/file/2014...
#
#                                          Name
# 19                                 Banco BISA
# 20                 Amaggi (Grupo André Maggi)
# 28                                  CAP Acero
# 29                                  CAP Acero
# 30                                  CAP Acero
# 597     Abu Dhabi Fund for Development (ADFD)
# 598  Abu Dhabi National Energy Company (TAQA)
# 838                                     COFCO

# %%
df_f2014=df_f2014.drop_duplicates()

# %%
df_f2014
# Out:
#                                                     URL  \
# 0     http://www.arcosdorados.com/attached/editorial...
# 1     http://portal.acabase.com.ar/Balances/BALANCES...
# 2     http://www.grupolucci.com.ar/pdf/Memoria-Grupo...
# 3     http://www.laserenisima.com.ar/encuesta/Report...
# 4     https://www.pfizer.com.ar/sites/g/files/g10025...
# ...                                                 ...
# 1656  http://www.besta.com.tw/upload/media/about/PDF...
# 1657  http://invepar.temp.w3br.com/midias/conteudo/p...
# 1658  https://www.investec.co.za/content/dam/investe...
# 1659  http://icb.org.bd/pdf/icb_annual_report_2013-2...
# 1660  http://www.invictaholdings.co.za/Financials/AR...
#
#                                           Name
# 0                      Arcos Dorados Argentina
# 1     Asociación de Cooperativas Argentinas CL
# 2                                  Grupo Lucci
# 3                             Mastellone Hnos.
# 4                             Pfizer Argentina
# ...                                        ...
# 1656                    Inventec Besta (Besta)
# 1657                                   Invepar
# 1658                                  Investec
# 1659      Investment Corporation of Bangladesh
# 1660                          Invicta Holdings
#
# [1653 rows x 2 columns]

# %%
ty
# Out:
#                    Name  Publication Year Report.PDF.Address   Size  \
# 34863  Invicta Holdings            2014.0                NaN  Large
#
#                    Sector       Country Country Status  Region Date Added  \
# 34863  Financial Services  South Africa      DAC-UMICT  Africa  28-7-2014
#
#                                Title  ...  \
# 34863  Integrated Annual Report 2014  ...
#
#       Assurance Standard: national (sustainability) Materiality Matters Check  \
# 34863                                            No                       NaN
#
#       GRI Service  Featured Report?   OS GOLD Community SDGs  \
# 34863         NaN               NaN  NaN            NaN  NaN
#
#                                       Report_Pdf_Address Report_PDF_Address_1  \
# 34863  http://www.invictaholdings.co.za/Financials/AR...                  NaN
#
#                                                   Unique
# 34863  http://www.invictaholdings.co.za/Financials/AR...
#
# [1 rows x 47 columns]

# %%
ll.nunique()
# Out:
# Name                                             5948
# Publication Year                                    1
# Report.PDF.Address                               1702
# Size                                                3
# Sector                                             38
# Country                                           102
# Country Status                                      6
# Region                                              6
# Date Added                                        807
# Title                                            2447
# Type                                                5
# Report Pdf Address                               4826
# Report Html Address                              2685
# Report Drt Address                                  0
# Database link                                    5969
# Adherence Level                                     9
# Status                                              3
# Application Level                                   0
# Sector Supplements (Final)                         12
# GRI Content Index URL                             830
# Integrated                                          2
# Organization type                                   8
# Listed/Non-listed                                   3
# OECD                                                2
# UNGC                                                2
# CDP                                                 2
# IFC                                                 2
# ISO                                                 2
# External Assurance                                  2
# Type of Assurance Provider                          3
# Assurance Provider                                 17
# Stakeholder Panel/ Expert Opinion                   2
# Assurance Scope                                     4
# Level of Assurance                                  4
# Assurance Standard: AA1000 AS                       2
# Assurance Stanadard: ISAE3000                       2
# Assurance Standard: national (general)              2
# Assurance Standard: national (sustainability)       2
# Materiality Matters Check                           2
# GRI Service                                         4
# Featured Report?                                    0
# OS                                                  0
# GOLD Community                                      0
# SDGs                                                0
# Report_Pdf_Address                               4827
# Report_PDF_Address_1                             1702
# Unique                                           3238
# dtype: int64

# %% [markdown]
# writer1 = pd.ExcelWriter('Thesis_2013.xlsx', engine='xlsxwriter')
# df_f2013.to_excel(writer1, sheet_name='Sheet1')
# writer1.save()  #its better to save after cleaning the data only once is enough
